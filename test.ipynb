# %% [markdown]
# <a href="https://colab.research.google.com/github/1ZHAO1/Learned-FISTA-CT/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 请替换以下三个变量为您自己的信息 ---
username = '1ZHAO1'                     # 您的GitHub用户名
repo = 'Learned-FISTA-CT'              # 您的仓库名
# -----------------------------------------

# 克隆您的私密仓库
# !git clone https://github.com/1ZHAO1/Learned-FISTA-CT.git

# 进入项目文件夹
# %cd {repo}

# 检查文件是否都已存在
# !ls
# Out:
# Cloning into 'Learned-FISTA-CT'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 21 (delta 8), reused 19 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 29.58 KiB | 465.00 KiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/Learned-FISTA-CT
# baseline_recon.py  generate_data.py  main.py	simple_unet.py
# fista_net_plus.py  loader.py	     README.md	solver.py

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# 安装Mamba以加速后续安装
# !conda install -n base conda-libmamba-solver -c conda-forge --yes
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda-libmamba-solver
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.8.3   |       hbd8a1cb_0         151 KB  conda-forge
#     certifi-2025.8.3           |     pyhd8ed1ab_0         155 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     openssl-3.5.2              |       h26f9b46_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
# %cd Learned-FISTA-CT
# Out:
# /content/Learned-FISTA-CT

# %%
# 使用Conda安装核心库
# !conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia --yes
# !conda install -c astra-toolbox astra-toolbox --yes

# 使用pip安装剩余的库
# !pip install scikit-image matplotlib tqdm
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=11.8
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       3_kmp_llvm           7 KB  conda-forge
#     aom-3.6.1                  |       h59595ed_0         2.6 MB  conda-forge
#     blas-2.116                 |              mkl          13 KB  conda-forge
#     blas-devel-3.9.0           |   16_linux64_mkl          12 KB  conda-forge
# ...

# %%
# !python generate_data.py
# Out:
# >> Step 0: Configuring data generation parameters...
# >> Starting data generation...
# >> Generating 1000 training samples...
# 100% 1000/1000 [00:07<00:00, 130.29it/s]
# >> Generating 200 testing samples...
# 100% 200/200 [00:01<00:00, 137.22it/s]
#
# Data generation complete!
# Dataset saved in: /content/Learned-FISTA-CT/dataset

# %%
# !python main.py \
    --mode train \
    --model_name SimpleUNet \
    --lr 1e-3 \
    --num_epochs 100 \
    --start_epoch 0
# Out:
# Configuration:
# Namespace(mode='train', model_name='SimpleUNet', data_path='./dataset', result_path='./results', num_epochs=100, start_epoch=0, batch_size=16, lr=0.001, num_workers=2, log_interval=10, test_epoch=100, multi_gpu=False, device=device(type='cuda'))
# Results and models will be saved in: /content/Learned-FISTA-CT/results/SimpleUNet
# Using device: cuda
# Loading dataset...
# Dataset loaded successfully.
# Preparing fixed test batch for solver...
# Initializing model: SimpleUNet
# Starting training...
# Train Epoch: 1 [0/1000 (0%)]	Batch Loss: 0.672468	 TIME:1.7s
# Train Epoch: 1 [160/1000 (16%)]	Batch Loss: 0.065165	 TIME:3.3s
# Train Epoch: 1 [320/1000 (32%)]	Batch Loss: 0.045125	 TIME:4.9s
# Train Epoch: 1 [480/1000 (48%)]	Batch Loss: 0.038979	 TIME:6.5s
# Train Epoch: 1 [640/1000 (63%)]	Batch Loss: 0.033428	 TIME:8.1s
# Train Epoch: 1 [800/1000 (79%)]	Batch Loss: 0.032127	 TIME:9.6s
# Train Epoch: 1 [960/1000 (95%)]	Batch Loss: 0.029045	 TIME:11.2s
# ...

# %%
# !python main.py --mode test --model_name SimpleUNet --test_epoch 15
# Out:
# Configuration:
# Namespace(mode='test', model_name='SimpleUNet', data_path='./dataset', result_path='./results', num_epochs=100, start_epoch=0, batch_size=16, lr=0.001, num_workers=2, log_interval=10, test_epoch=15, multi_gpu=False, device=device(type='cuda'))
# Results and models will be saved in: /content/Learned-FISTA-CT/results/SimpleUNet
# Using device: cuda
# Loading dataset...
# Dataset loaded successfully.
# Preparing fixed test batch for solver...
# Initializing model: SimpleUNet
# Starting testing...
# 从 epoch 15 加载模型成功。
# /content/Learned-FISTA-CT/solver.py:173: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from font(s) DejaVu Sans.
#   plt.savefig(pjoin(vis_path, f'comparison_batch_{i}_img_{j}.png'))
# /content/Learned-FISTA-CT/solver.py:173: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   plt.savefig(pjoin(vis_path, f'comparison_batch_{i}_img_{j}.png'))
# ...
